# %% [markdown]
# ##                              Handling Missing Values
# In order to check missing values in Pandas DataFrame, we use a function isnull() and notnull(). Both
# function help in checking whether a value is NaN or not. These function can also be used in Pandas
# Series in order to find null values in a series.

# %% [markdown]
# ## DataSet
#
# https://drive.google.com/file/d/19xAmWZP6rV2q8goKM0id_GcFdrgeduyt/view?usp=share_link

# %% [markdown]
# # Checking for missing values using isnull() and notnull()

# %%
# importing pandas as pd 
import pandas as pd 
 
# importing numpy as np 
import numpy as np 
 
# Read the dataset 
df=pd.read_csv("Universities_Schoolarships_All_Around_the_World.csv")
 
# using isnull() function 
df.isnull()
# Out:
#      Unnamed: 0  title  degrees  funds   date  location
# 0         False  False    False  False  False     False
# 1         False  False    False  False  False     False
# 2         False  False    False  False  False     False
# 3         False  False    False  False  False     False
# 4         False  False    False  False  False     False
# ..          ...    ...      ...    ...    ...       ...
# 874       False  False     True   True   True     False
# 875       False  False     True   True   True     False
# 876       False  False     True   True   True     False
# 877       False  False     True   True   True     False
# 878       False  False     True   True   True     False
#
# [879 rows x 6 columns]

# %%
#display information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  879 non-null    int64
#  1   title       879 non-null    object
#  2   degrees     830 non-null    object
#  3   funds       794 non-null    object
#  4   date        588 non-null    object
#  5   location    879 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 41.3+ KB

# %%
#count the number of null vaues
df.isnull().sum()
# Out:
# Unnamed: 0      0
# title           0
# degrees        49
# funds          85
# date          291
# location        0
# dtype: int64

# %%
# importing pandas package
import pandas as pd

# Read the dataset 
df=pd.read_csv("Universities_Schoolarships_All_Around_the_World.csv")

# creating bool series True for NaN values
bool_series = pd.isnull(df["funds"])

# filtering data
# displaying data only with Gender = NaN
df[bool_series]
# Out:
#      Unnamed: 0                                              title   degrees  \
# 29           29                     PhD Studentships in Electronic       Phd
# 188         188  UFIC Diane Fisher Awards for International Stu...  Bachelor
# 194         194  Thomas A Plein Endowed funding for Internation...  Bachelor
# 203         203  UFIC Diane Fisher Awards for International Stu...  Bachelor
# 209         209  Thomas A Plein Endowed funding for Internation...  Bachelor
# ..          ...                                                ...       ...
# 874         874  Rhodes Scholarships in Oxford University for S...       NaN
# 875         875  Nottingham Trent University Science Scholarshi...       NaN
# 876         876  Sussex Chancellor’s International Research Sch...       NaN
# 877         877  UWE Chancellor’s Scholarships for Internationa...       NaN
# 878         878  Swansea University International Excellence Sc...       NaN
#
#     funds             date        location
# 29    NaN  3 December 2022  united-kingdom
# 188   NaN              NaN    south-africa
# 194   NaN              NaN    south-africa
# 203   NaN              NaN         nigeria
# 209   NaN              NaN         nigeria
# ..    ...              ...             ...
# 874   NaN              NaN  united-kingdom
# 875   NaN              NaN  united-kingdom
# 876   NaN              NaN  united-kingdom
# 877   NaN              NaN  united-kingdom
# 878   NaN              NaN  united-kingdom
#
# [85 rows x 6 columns]

# %% [markdown]
# # Checking for missing values using notnull()
# In order to check null values in Pandas Dataframe, we use notnull() function this function return
# dataframe of Boolean values which are False for NaN values.

# %%
# importing pandas as pd
import pandas as pd
# importing numpy as np
import numpy as np


#read dataset
df=pd.read_csv("Universities_Schoolarships_All_Around_the_World.csv")

# using notnull() function
df.notnull()
# Out:
#      Unnamed: 0  title  degrees  funds   date  location
# 0          True   True     True   True   True      True
# 1          True   True     True   True   True      True
# 2          True   True     True   True   True      True
# 3          True   True     True   True   True      True
# 4          True   True     True   True   True      True
# ..          ...    ...      ...    ...    ...       ...
# 874        True   True    False  False  False      True
# 875        True   True    False  False  False      True
# 876        True   True    False  False  False      True
# 877        True   True    False  False  False      True
# 878        True   True    False  False  False      True
#
# [879 rows x 6 columns]

# %%
# importing pandas package
import pandas as pd

# Read the dataset 
df=pd.read_csv("Universities_Schoolarships_All_Around_the_World.csv")

# creating bool series True for NaN values
bool_series = pd.notnull(df["funds"])

# filtering data
# displaying data only with Gender = NaN
df[bool_series]
# Out:
#      Unnamed: 0                                              title  \
# 0             0       Schaefer Halleen’s Social Equity Scholarship
# 1             1                President’s Scholarship for Ukraine
# 2             2  International Students Diversity Contest 2022-...
# 3             3  Master in Business Administration 80% OFF your...
# 4             4                   Improve Men’s Health Scholarship
# ..          ...                                                ...
# 830         830  Wolfson Postgraduate Scholarships in the Human...
# 831         831                       Durham Doctoral Studentships
# 832         832        Sir Henry Wellcome Postdoctoral Fellowships
# 833         833  Heriot-Watt Scholarships and bursaries for UK ...
# 834         834                The Keith Murray Senior Scholarship
#
#                            degrees             funds               date  \
# 0            Master, Bachelor, Phd             $1000       30 June 2022
# 1    Master, Bachelor, Phd, Course             $2500       31 July 2022
# 2    Master, Bachelor, Phd, Course      Up to $2,000   22 December 2022
# 3                           Master  80% Tuition Fees  15 September 2022
# 4            Master, Bachelor, Phd             $2000        31 May 2022
# ..                             ...               ...                ...
# 830                            Phd  Partially Funded      Always Active
# 831                            Phd  Partially Funded      Always Active
# 832                            Phd      Fully Funded      Always Active
# 833          Bachelor, Master, Phd  Partially Funded      Always Active
# 834                         Master       Course fees        22 May 2022
#
#            location
# 0     united-states
# 1     united-states
# 2     united-states
# 3     united-states
# 4     united-states
# ..              ...
# 830  united-kingdom
# 831  united-kingdom
# 832  united-kingdom
# 833  united-kingdom
# 834  united-kingdom
#
# [794 rows x 6 columns]

# %% [markdown]
# # Filling missing values using fillna(), replace() and interpolate()
#
# In order to fill null values in a datasets, we use fillna(), replace() and interpolate() function these
# function replace NaN values with some value of their own. All these function help in filling a null
# values in datasets of a DataFrame. Interpolate() function is basically used to fill NA values in the
# dataframe but it uses various interpolation technique to fill the missing values rather than hardcoding the value.

# %% [markdown]
# Code #1: Filling null values with a single value

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np


# Read the dataset 
df=pd.read_csv("Universities_Schoolarships_All_Around_the_World.csv")

#filling missing value using fillna()
df.fillna(0)
# Out:
#      Unnamed: 0                                              title  \
# 0             0       Schaefer Halleen’s Social Equity Scholarship
# 1             1                President’s Scholarship for Ukraine
# 2             2  International Students Diversity Contest 2022-...
# 3             3  Master in Business Administration 80% OFF your...
# 4             4                   Improve Men’s Health Scholarship
# ..          ...                                                ...
# 874         874  Rhodes Scholarships in Oxford University for S...
# 875         875  Nottingham Trent University Science Scholarshi...
# 876         876  Sussex Chancellor’s International Research Sch...
# 877         877  UWE Chancellor’s Scholarships for Internationa...
# 878         878  Swansea University International Excellence Sc...
#
#                            degrees             funds               date  \
# 0            Master, Bachelor, Phd             $1000       30 June 2022
# 1    Master, Bachelor, Phd, Course             $2500       31 July 2022
# 2    Master, Bachelor, Phd, Course      Up to $2,000   22 December 2022
# 3                           Master  80% Tuition Fees  15 September 2022
# 4            Master, Bachelor, Phd             $2000        31 May 2022
# ..                             ...               ...                ...
# 874                              0                 0                  0
# 875                              0                 0                  0
# 876                              0                 0                  0
# 877                              0                 0                  0
# 878                              0                 0                  0
#
#            location
# 0     united-states
# 1     united-states
# 2     united-states
# 3     united-states
# 4     united-states
# ..              ...
# 874  united-kingdom
# 875  united-kingdom
# 876  united-kingdom
# 877  united-kingdom
# 878  united-kingdom
#
# [879 rows x 6 columns]

# %% [markdown]
# Code #2: Filling null values with the previous ones

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# Read the dataset 
df=pd.read_csv("Universities_Schoolarships_All_Around_the_World.csv")

# filling a missing value with
# previous ones
df.fillna(method ='pad')
# Out:
#      Unnamed: 0                                              title  \
# 0             0       Schaefer Halleen’s Social Equity Scholarship
# 1             1                President’s Scholarship for Ukraine
# 2             2  International Students Diversity Contest 2022-...
# 3             3  Master in Business Administration 80% OFF your...
# 4             4                   Improve Men’s Health Scholarship
# ..          ...                                                ...
# 874         874  Rhodes Scholarships in Oxford University for S...
# 875         875  Nottingham Trent University Science Scholarshi...
# 876         876  Sussex Chancellor’s International Research Sch...
# 877         877  UWE Chancellor’s Scholarships for Internationa...
# 878         878  Swansea University International Excellence Sc...
#
#                            degrees             funds               date  \
# 0            Master, Bachelor, Phd             $1000       30 June 2022
# 1    Master, Bachelor, Phd, Course             $2500       31 July 2022
# 2    Master, Bachelor, Phd, Course      Up to $2,000   22 December 2022
# 3                           Master  80% Tuition Fees  15 September 2022
# 4            Master, Bachelor, Phd             $2000        31 May 2022
# ..                             ...               ...                ...
# 874                         Master       Course fees        22 May 2022
# 875                         Master       Course fees        22 May 2022
# 876                         Master       Course fees        22 May 2022
# 877                         Master       Course fees        22 May 2022
# 878                         Master       Course fees        22 May 2022
#
#            location
# 0     united-states
# 1     united-states
# 2     united-states
# 3     united-states
# 4     united-states
# ..              ...
# 874  united-kingdom
# 875  united-kingdom
# 876  united-kingdom
# 877  united-kingdom
# 878  united-kingdom
#
# [879 rows x 6 columns]

# %% [markdown]
# Code #3: Filling null value with the next ones

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# Read the dataset 
df=pd.read_csv("Universities_Schoolarships_All_Around_the_World.csv")

# filling null value using fillna() function
df.fillna(method ='bfill')
# Out:
#      Unnamed: 0                                              title  \
# 0             0       Schaefer Halleen’s Social Equity Scholarship
# 1             1                President’s Scholarship for Ukraine
# 2             2  International Students Diversity Contest 2022-...
# 3             3  Master in Business Administration 80% OFF your...
# 4             4                   Improve Men’s Health Scholarship
# ..          ...                                                ...
# 874         874  Rhodes Scholarships in Oxford University for S...
# 875         875  Nottingham Trent University Science Scholarshi...
# 876         876  Sussex Chancellor’s International Research Sch...
# 877         877  UWE Chancellor’s Scholarships for Internationa...
# 878         878  Swansea University International Excellence Sc...
#
#                            degrees             funds               date  \
# 0            Master, Bachelor, Phd             $1000       30 June 2022
# 1    Master, Bachelor, Phd, Course             $2500       31 July 2022
# 2    Master, Bachelor, Phd, Course      Up to $2,000   22 December 2022
# 3                           Master  80% Tuition Fees  15 September 2022
# 4            Master, Bachelor, Phd             $2000        31 May 2022
# ..                             ...               ...                ...
# 874                            NaN               NaN                NaN
# 875                            NaN               NaN                NaN
# 876                            NaN               NaN                NaN
# 877                            NaN               NaN                NaN
# 878                            NaN               NaN                NaN
#
#            location
# 0     united-states
# 1     united-states
# 2     united-states
# 3     united-states
# 4     united-states
# ..              ...
# 874  united-kingdom
# 875  united-kingdom
# 876  united-kingdom
# 877  united-kingdom
# 878  united-kingdom
#
# [879 rows x 6 columns]

# %% [markdown]
# Code #4: Filling null values in CSV File

# %%
# importing pandas package
import pandas as pd

# Read the dataset 
df=pd.read_csv("Universities_Schoolarships_All_Around_the_World.csv")

# Printing the first 10 to 24 rows of
# the data frame for visualization
df[10:25]
# Out:
#     Unnamed: 0                                              title  \
# 10          10          LAPTOP Scholarships - study Supply Chains
# 11          11  Medicine: Fully Funded Swansea & HMRI PhD Scho...
# 12          12    New York University - September 11 Scholarships
# 13          13                          TKS Full-Ride Scholarship
# 14          14  Five scholarships of up to US$3000 for supply ...
# 15          15    GREAT Scholarship for Bangladesh Students in UK
# 16          16  Diversity Scholarships for Africa and Latin Am...
# 17          17  Beth Mead Scholarships for International Stude...
# 18          18  Malaysia Scholarships at Nottingham Trent Univ...
# 19          19  PhD Studentships in Predictive Uncertainty in ...
# 20          20  Strathclyde Business School MRes Scholarships ...
# 21          21  International Students Diversity Contest 2022-...
# 22          22  Master in Business Administration 80% OFF your...
# 23          23  3 Month F1 Visa Study English in USA Scholarsh...
# 24          24                                        ArtUniverse
#
#                           degrees  \
# 10  Master, Bachelor, Phd, Course
# 11                            Phd
# 12  Master, Bachelor, Phd, Course
# 13                         Course
# 14  Master, Bachelor, Phd, Course
# 15                         Master
# 16                         Master
# 17               Bachelor, Master
# 18                         Master
# 19                         Master
# 20                         Master
# 21  Master, Bachelor, Phd, Course
# 22                         Master
# 23                         Course
# 24                 Master, Course
#
#                                                 funds               date  \
# 10                                        up to $3000         6 May 2022
# 11    Full cost of tuition fees and an annual stipend         6 May 2022
# 12                         Pay any remaining balance.       30 June 2023
# 13                100% Tuition Fee [value of $6,000+]        31 May 2022
# 14                                              $3000         6 May 2022
# 15                                            £10,000        31 May 2022
# 16                                    50% scholarship        31 May 2022
# 17                                             £1,200     31 August 2022
# 18                                             £4,000       29 June 2022
# 19  £16,062 p.a., tuition fees + £2,000 research g...       10 June 2022
# 20                                       Tuition fees                NaN
# 21                                       Up to $2,000   22 December 2022
# 22                                   80% Tuition Fees  15 September 2022
# 23                                              $1455        1 July 2022
# 24                        Full or partial scholarship   30 December 2022
#
#           location
# 10   united-states
# 11   united-states
# 12   united-states
# 13   united-states
# 14   united-states
# 15  united-kingdom
# 16  united-kingdom
# 17  united-kingdom
# 18  united-kingdom
# 19  united-kingdom
# 20  united-kingdom
# 21  united-kingdom
# 22  united-kingdom
# 23  united-kingdom
# 24  united-kingdom

# %% [markdown]
# Now we are going to fill all the null values in funds column with “Not funded”

# %%
# importing pandas package
import pandas as pd
import numpy as np

# Read the dataset 
df=pd.read_csv("Universities_Schoolarships_All_Around_the_World.csv")

df["funds"]=df["funds"].fillna("Not funded")
df["funds"].isnull().sum()
# Out:
# 0

# %% [markdown]
# Now we are going to fill all the null values of degrees column with “No qualitfication”

# %%
# importing pandas package
import pandas as pd
import numpy as np

# Read the dataset 
df=pd.read_csv("Universities_Schoolarships_All_Around_the_World.csv")

df["degrees"]=df["degrees"].fillna("No Qualification")
df["degrees"].isnull().sum()
# Out:
# 0

# %% [markdown]
# Code #5: Filling a null values using replace() method

# %%
# importing pandas package
import pandas as pd
# making data frame from csv file

# Read the dataset 
data=pd.read_csv("Universities_Schoolarships_All_Around_the_World.csv")

# Printing the first 10 to 24 rows of
# the data frame for visualization
data[10:25]
# Out:
#     Unnamed: 0                                              title  \
# 10          10          LAPTOP Scholarships - study Supply Chains
# 11          11  Medicine: Fully Funded Swansea & HMRI PhD Scho...
# 12          12    New York University - September 11 Scholarships
# 13          13                          TKS Full-Ride Scholarship
# 14          14  Five scholarships of up to US$3000 for supply ...
# 15          15    GREAT Scholarship for Bangladesh Students in UK
# 16          16  Diversity Scholarships for Africa and Latin Am...
# 17          17  Beth Mead Scholarships for International Stude...
# 18          18  Malaysia Scholarships at Nottingham Trent Univ...
# 19          19  PhD Studentships in Predictive Uncertainty in ...
# 20          20  Strathclyde Business School MRes Scholarships ...
# 21          21  International Students Diversity Contest 2022-...
# 22          22  Master in Business Administration 80% OFF your...
# 23          23  3 Month F1 Visa Study English in USA Scholarsh...
# 24          24                                        ArtUniverse
#
#                           degrees  \
# 10  Master, Bachelor, Phd, Course
# 11                            Phd
# 12  Master, Bachelor, Phd, Course
# 13                         Course
# 14  Master, Bachelor, Phd, Course
# 15                         Master
# 16                         Master
# 17               Bachelor, Master
# 18                         Master
# 19                         Master
# 20                         Master
# 21  Master, Bachelor, Phd, Course
# 22                         Master
# 23                         Course
# 24                 Master, Course
#
#                                                 funds               date  \
# 10                                        up to $3000         6 May 2022
# 11    Full cost of tuition fees and an annual stipend         6 May 2022
# 12                         Pay any remaining balance.       30 June 2023
# 13                100% Tuition Fee [value of $6,000+]        31 May 2022
# 14                                              $3000         6 May 2022
# 15                                            £10,000        31 May 2022
# 16                                    50% scholarship        31 May 2022
# 17                                             £1,200     31 August 2022
# 18                                             £4,000       29 June 2022
# 19  £16,062 p.a., tuition fees + £2,000 research g...       10 June 2022
# 20                                       Tuition fees                NaN
# 21                                       Up to $2,000   22 December 2022
# 22                                   80% Tuition Fees  15 September 2022
# 23                                              $1455        1 July 2022
# 24                        Full or partial scholarship   30 December 2022
#
#           location
# 10   united-states
# 11   united-states
# 12   united-states
# 13   united-states
# 14   united-states
# 15  united-kingdom
# 16  united-kingdom
# 17  united-kingdom
# 18  united-kingdom
# 19  united-kingdom
# 20  united-kingdom
# 21  united-kingdom
# 22  united-kingdom
# 23  united-kingdom
# 24  united-kingdom

# %% [markdown]
# Now we are going to replace the all Nan value in the data frame with -99 value

# %%
# importing pandas package
import pandas as pd
import numpy as np
# Read the dataset 
data=pd.read_csv("Universities_Schoolarships_All_Around_the_World.csv")

# will replace Nan value in dataframe with value -99
data.replace(to_replace = np.nan, value = -99)
# Out:
#      Unnamed: 0                                              title  \
# 0             0       Schaefer Halleen’s Social Equity Scholarship
# 1             1                President’s Scholarship for Ukraine
# 2             2  International Students Diversity Contest 2022-...
# 3             3  Master in Business Administration 80% OFF your...
# 4             4                   Improve Men’s Health Scholarship
# ..          ...                                                ...
# 874         874  Rhodes Scholarships in Oxford University for S...
# 875         875  Nottingham Trent University Science Scholarshi...
# 876         876  Sussex Chancellor’s International Research Sch...
# 877         877  UWE Chancellor’s Scholarships for Internationa...
# 878         878  Swansea University International Excellence Sc...
#
#                            degrees             funds               date  \
# 0            Master, Bachelor, Phd             $1000       30 June 2022
# 1    Master, Bachelor, Phd, Course             $2500       31 July 2022
# 2    Master, Bachelor, Phd, Course      Up to $2,000   22 December 2022
# 3                           Master  80% Tuition Fees  15 September 2022
# 4            Master, Bachelor, Phd             $2000        31 May 2022
# ..                             ...               ...                ...
# 874                            -99               -99                -99
# 875                            -99               -99                -99
# 876                            -99               -99                -99
# 877                            -99               -99                -99
# 878                            -99               -99                -99
#
#            location
# 0     united-states
# 1     united-states
# 2     united-states
# 3     united-states
# 4     united-states
# ..              ...
# 874  united-kingdom
# 875  united-kingdom
# 876  united-kingdom
# 877  united-kingdom
# 878  united-kingdom
#
# [879 rows x 6 columns]

# %% [markdown]
# Code #6: Using interpolate() function to fill the missing values using linear method.

# %%
# importing pandas as pd
import pandas as pd
import numpy as np

# Read the dataset 
df=pd.read_csv("Universities_Schoolarships_All_Around_the_World.csv")
# Print the dataframe
df
# Out:
#      Unnamed: 0                                              title  \
# 0             0       Schaefer Halleen’s Social Equity Scholarship
# 1             1                President’s Scholarship for Ukraine
# 2             2  International Students Diversity Contest 2022-...
# 3             3  Master in Business Administration 80% OFF your...
# 4             4                   Improve Men’s Health Scholarship
# ..          ...                                                ...
# 874         874  Rhodes Scholarships in Oxford University for S...
# 875         875  Nottingham Trent University Science Scholarshi...
# 876         876  Sussex Chancellor’s International Research Sch...
# 877         877  UWE Chancellor’s Scholarships for Internationa...
# 878         878  Swansea University International Excellence Sc...
#
#                            degrees             funds               date  \
# 0            Master, Bachelor, Phd             $1000       30 June 2022
# 1    Master, Bachelor, Phd, Course             $2500       31 July 2022
# 2    Master, Bachelor, Phd, Course      Up to $2,000   22 December 2022
# 3                           Master  80% Tuition Fees  15 September 2022
# 4            Master, Bachelor, Phd             $2000        31 May 2022
# ..                             ...               ...                ...
# 874                            NaN               NaN                NaN
# 875                            NaN               NaN                NaN
# 876                            NaN               NaN                NaN
# 877                            NaN               NaN                NaN
# 878                            NaN               NaN                NaN
#
#            location
# 0     united-states
# 1     united-states
# 2     united-states
# 3     united-states
# 4     united-states
# ..              ...
# 874  united-kingdom
# 875  united-kingdom
# 876  united-kingdom
# 877  united-kingdom
# 878  united-kingdom
#
# [879 rows x 6 columns]

# %% [markdown]
# let’s interpolate the missing values using Linear method.

# %%
# to interpolate the missing values
df.interpolate(method ='linear', limit_direction ='forward')
# Out:
#      Unnamed: 0                                              title  \
# 0             0       Schaefer Halleen’s Social Equity Scholarship
# 1             1                President’s Scholarship for Ukraine
# 2             2  International Students Diversity Contest 2022-...
# 3             3  Master in Business Administration 80% OFF your...
# 4             4                   Improve Men’s Health Scholarship
# ..          ...                                                ...
# 874         874  Rhodes Scholarships in Oxford University for S...
# 875         875  Nottingham Trent University Science Scholarshi...
# 876         876  Sussex Chancellor’s International Research Sch...
# 877         877  UWE Chancellor’s Scholarships for Internationa...
# 878         878  Swansea University International Excellence Sc...
#
#                            degrees             funds               date  \
# 0            Master, Bachelor, Phd             $1000       30 June 2022
# 1    Master, Bachelor, Phd, Course             $2500       31 July 2022
# 2    Master, Bachelor, Phd, Course      Up to $2,000   22 December 2022
# 3                           Master  80% Tuition Fees  15 September 2022
# 4            Master, Bachelor, Phd             $2000        31 May 2022
# ..                             ...               ...                ...
# 874                            NaN               NaN                NaN
# 875                            NaN               NaN                NaN
# 876                            NaN               NaN                NaN
# 877                            NaN               NaN                NaN
# 878                            NaN               NaN                NaN
#
#            location
# 0     united-states
# 1     united-states
# 2     united-states
# 3     united-states
# 4     united-states
# ..              ...
# 874  united-kingdom
# 875  united-kingdom
# 876  united-kingdom
# 877  united-kingdom
# 878  united-kingdom
#
# [879 rows x 6 columns]

# %% [markdown]
# As we can see the output, values in the first row could not get filled as the direction of filling of
# values is forward and there is no previous value which could have been used in interpolation.

# %% [markdown]
# # Dropping missing values using dropna()
# In order to drop a null values from a dataframe, we used dropna() function this function drop
# Rows/Columns of datasets with Null values in different ways.

# %% [markdown]
# Code #1: Dropping rows with at least 1 null value

# %%
# importing pandas as pd
import pandas as pd
# importing numpy as np
import numpy as np

# Read the dataset 
df=pd.read_csv("Universities_Schoolarships_All_Around_the_World.csv")
df
# Out:
#      Unnamed: 0                                              title  \
# 0             0       Schaefer Halleen’s Social Equity Scholarship
# 1             1                President’s Scholarship for Ukraine
# 2             2  International Students Diversity Contest 2022-...
# 3             3  Master in Business Administration 80% OFF your...
# 4             4                   Improve Men’s Health Scholarship
# ..          ...                                                ...
# 874         874  Rhodes Scholarships in Oxford University for S...
# 875         875  Nottingham Trent University Science Scholarshi...
# 876         876  Sussex Chancellor’s International Research Sch...
# 877         877  UWE Chancellor’s Scholarships for Internationa...
# 878         878  Swansea University International Excellence Sc...
#
#                            degrees             funds               date  \
# 0            Master, Bachelor, Phd             $1000       30 June 2022
# 1    Master, Bachelor, Phd, Course             $2500       31 July 2022
# 2    Master, Bachelor, Phd, Course      Up to $2,000   22 December 2022
# 3                           Master  80% Tuition Fees  15 September 2022
# 4            Master, Bachelor, Phd             $2000        31 May 2022
# ..                             ...               ...                ...
# 874                            NaN               NaN                NaN
# 875                            NaN               NaN                NaN
# 876                            NaN               NaN                NaN
# 877                            NaN               NaN                NaN
# 878                            NaN               NaN                NaN
#
#            location
# 0     united-states
# 1     united-states
# 2     united-states
# 3     united-states
# 4     united-states
# ..              ...
# 874  united-kingdom
# 875  united-kingdom
# 876  united-kingdom
# 877  united-kingdom
# 878  united-kingdom
#
# [879 rows x 6 columns]

# %% [markdown]
# Now we drop rows with at least one Nan value (Null value)

# %%
# importing pandas as pd
import pandas as pd
# importing numpy as np
import numpy as np
# Read the dataset 
df=pd.read_csv("Universities_Schoolarships_All_Around_the_World.csv")

# using dropna() function
df.dropna()
# Out:
#      Unnamed: 0                                              title  \
# 0             0       Schaefer Halleen’s Social Equity Scholarship
# 1             1                President’s Scholarship for Ukraine
# 2             2  International Students Diversity Contest 2022-...
# 3             3  Master in Business Administration 80% OFF your...
# 4             4                   Improve Men’s Health Scholarship
# ..          ...                                                ...
# 830         830  Wolfson Postgraduate Scholarships in the Human...
# 831         831                       Durham Doctoral Studentships
# 832         832        Sir Henry Wellcome Postdoctoral Fellowships
# 833         833  Heriot-Watt Scholarships and bursaries for UK ...
# 834         834                The Keith Murray Senior Scholarship
#
#                            degrees             funds               date  \
# 0            Master, Bachelor, Phd             $1000       30 June 2022
# 1    Master, Bachelor, Phd, Course             $2500       31 July 2022
# 2    Master, Bachelor, Phd, Course      Up to $2,000   22 December 2022
# 3                           Master  80% Tuition Fees  15 September 2022
# 4            Master, Bachelor, Phd             $2000        31 May 2022
# ..                             ...               ...                ...
# 830                            Phd  Partially Funded      Always Active
# 831                            Phd  Partially Funded      Always Active
# 832                            Phd      Fully Funded      Always Active
# 833          Bachelor, Master, Phd  Partially Funded      Always Active
# 834                         Master       Course fees        22 May 2022
#
#            location
# 0     united-states
# 1     united-states
# 2     united-states
# 3     united-states
# 4     united-states
# ..              ...
# 830  united-kingdom
# 831  united-kingdom
# 832  united-kingdom
# 833  united-kingdom
# 834  united-kingdom
#
# [558 rows x 6 columns]

# %% [markdown]
# Code #2: Dropping rows if all values in that row are missing.

# %%
#importing pandas as pd
import pandas as pd
# importing numpy as np
import numpy as np


# Read the dataset 
df=pd.read_csv("Universities_Schoolarships_All_Around_the_World.csv")

# using dropna() function
df.dropna(how = 'all')
# Out:
#      Unnamed: 0                                              title  \
# 0             0       Schaefer Halleen’s Social Equity Scholarship
# 1             1                President’s Scholarship for Ukraine
# 2             2  International Students Diversity Contest 2022-...
# 3             3  Master in Business Administration 80% OFF your...
# 4             4                   Improve Men’s Health Scholarship
# ..          ...                                                ...
# 874         874  Rhodes Scholarships in Oxford University for S...
# 875         875  Nottingham Trent University Science Scholarshi...
# 876         876  Sussex Chancellor’s International Research Sch...
# 877         877  UWE Chancellor’s Scholarships for Internationa...
# 878         878  Swansea University International Excellence Sc...
#
#                            degrees             funds               date  \
# 0            Master, Bachelor, Phd             $1000       30 June 2022
# 1    Master, Bachelor, Phd, Course             $2500       31 July 2022
# 2    Master, Bachelor, Phd, Course      Up to $2,000   22 December 2022
# 3                           Master  80% Tuition Fees  15 September 2022
# 4            Master, Bachelor, Phd             $2000        31 May 2022
# ..                             ...               ...                ...
# 874                            NaN               NaN                NaN
# 875                            NaN               NaN                NaN
# 876                            NaN               NaN                NaN
# 877                            NaN               NaN                NaN
# 878                            NaN               NaN                NaN
#
#            location
# 0     united-states
# 1     united-states
# 2     united-states
# 3     united-states
# 4     united-states
# ..              ...
# 874  united-kingdom
# 875  united-kingdom
# 876  united-kingdom
# 877  united-kingdom
# 878  united-kingdom
#
# [879 rows x 6 columns]

# %% [markdown]
# Code #3: Dropping columns with at least 1 null value.

# %%
# importing pandas as pd
import pandas as pd
# importing numpy as np
import numpy as np


# Read the dataset 
df=pd.read_csv("Universities_Schoolarships_All_Around_the_World.csv")

# using dropna() function
df.dropna(axis = 1)
# Out:
#      Unnamed: 0                                              title  \
# 0             0       Schaefer Halleen’s Social Equity Scholarship
# 1             1                President’s Scholarship for Ukraine
# 2             2  International Students Diversity Contest 2022-...
# 3             3  Master in Business Administration 80% OFF your...
# 4             4                   Improve Men’s Health Scholarship
# ..          ...                                                ...
# 874         874  Rhodes Scholarships in Oxford University for S...
# 875         875  Nottingham Trent University Science Scholarshi...
# 876         876  Sussex Chancellor’s International Research Sch...
# 877         877  UWE Chancellor’s Scholarships for Internationa...
# 878         878  Swansea University International Excellence Sc...
#
#            location
# 0     united-states
# 1     united-states
# 2     united-states
# 3     united-states
# 4     united-states
# ..              ...
# 874  united-kingdom
# 875  united-kingdom
# 876  united-kingdom
# 877  united-kingdom
# 878  united-kingdom
#
# [879 rows x 3 columns]

# %% [markdown]
# Code #4: Dropping Rows with at least 1 null value in CSV file

# %%
# importing pandas module
import pandas as pd

# Read the dataset 
data=pd.read_csv("Universities_Schoolarships_All_Around_the_World.csv")

new_data = data.dropna(axis = 0, how ='any')
new_data
# Out:
#      Unnamed: 0                                              title  \
# 0             0       Schaefer Halleen’s Social Equity Scholarship
# 1             1                President’s Scholarship for Ukraine
# 2             2  International Students Diversity Contest 2022-...
# 3             3  Master in Business Administration 80% OFF your...
# 4             4                   Improve Men’s Health Scholarship
# ..          ...                                                ...
# 830         830  Wolfson Postgraduate Scholarships in the Human...
# 831         831                       Durham Doctoral Studentships
# 832         832        Sir Henry Wellcome Postdoctoral Fellowships
# 833         833  Heriot-Watt Scholarships and bursaries for UK ...
# 834         834                The Keith Murray Senior Scholarship
#
#                            degrees             funds               date  \
# 0            Master, Bachelor, Phd             $1000       30 June 2022
# 1    Master, Bachelor, Phd, Course             $2500       31 July 2022
# 2    Master, Bachelor, Phd, Course      Up to $2,000   22 December 2022
# 3                           Master  80% Tuition Fees  15 September 2022
# 4            Master, Bachelor, Phd             $2000        31 May 2022
# ..                             ...               ...                ...
# 830                            Phd  Partially Funded      Always Active
# 831                            Phd  Partially Funded      Always Active
# 832                            Phd      Fully Funded      Always Active
# 833          Bachelor, Master, Phd  Partially Funded      Always Active
# 834                         Master       Course fees        22 May 2022
#
#            location
# 0     united-states
# 1     united-states
# 2     united-states
# 3     united-states
# 4     united-states
# ..              ...
# 830  united-kingdom
# 831  united-kingdom
# 832  united-kingdom
# 833  united-kingdom
# 834  united-kingdom
#
# [558 rows x 6 columns]

# %% [markdown]
# Now we compare sizes of data frames so that we can come to know how many rows had at least 1
# Null value

# %%
print("Old data frame length:", len(data))
print("New data frame length:", len(new_data))
print("Number of rows with at least 1 NA value: ", (len(data)-len(new_data)))
# Out:
# Old data frame length: 879
# New data frame length: 558
# Number of rows with at least 1 NA value:  321

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------------
